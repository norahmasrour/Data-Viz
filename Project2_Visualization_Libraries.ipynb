# %% [markdown]
# # Python Visualization Libraries
# Using the following Python visualization libraries for our datasets for the final project:
#
# - Matplotlib
# - Folium

# %% [markdown]
# ## Matplotlib
# Using the Cummulative_Sum_by_Year_Full_Data_data.csv, we plot the storage capacity over the years.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
file_path = 'Cummulative_Sum_by_Year_Full_Data_data.csv'
data = pd.read_csv(file_path)

# Extract the Year and Storage Capacity columns for plotting
year = data['Year']
storage_capacity = data['Storage Capacity (kWh)']

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(year, storage_capacity, label='Storage Capacity (kWh)', marker='o')
plt.title('Year vs. Storage Capacity')
plt.xlabel('Year')
plt.ylabel('Storage Capacity (kWh)')
plt.legend()
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Dataset Mapping with Folium
# Using the Global_Map_Full_Data_data.csv, we map locations and power of project.

# %%
import pandas as pd
import folium

energy = pd.read_csv('Global_Map_Full_Data_data.csv')

# Assuming 'Rated Capacity (kWh)' is your capacity column
energy['marker_size'] = energy['Rated Capacity (kWh)'] / 1000000

# Create folium map
map_energy = folium.Map(location=[36, -119], zoom_start=6)

# Add CircleMarkers with varying sizes to the map
for _, row in energy.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=row['marker_size'],
        popup=f"Capacity (kWh): ${row['Rated Capacity (kWh)']} | Power (kW): {row['Rated Power (kW)']:.1f}",
        color="blue",
        fill=True,
        fill_color="blue"
    ).add_to(map_energy)

# Display the map
map_energy
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf6de959ce90e2ef6893212373d8f89c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf6de959ce90e2ef6893212373d8f89c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf6de959ce90e2ef6893212373d8f89c = L.map(
#                 &quot;map_bf6de959ce90e2ef6893212373d8f89c&quot;,
#                 {
#                     center: [36.0, -119.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1035747e0772b81fc6b0260d8ca9f789 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1035747e0772b81fc6b0260d8ca9f789.addTo(map_bf6de959ce90e2ef6893212373d8f89c);
#
#
#             var circle_marker_896eda51b8f5a76640c7ef963dcb59eb = L.circleMarker(
#                 [37.4537502, -90.84],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.52, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bf6de959ce90e2ef6893212373d8f89c);
#
#
#         var popup_86b5466439e57b6addeeb70534fbea6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_396236fb41b4673a4aed4cddaf7f68af = $(`&lt;div id=&quot;html_396236fb41b4673a4aed4cddaf7f68af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity (kWh): $3520000.0 | Power (kW): 440000.0&lt;/div&gt;`)[0];
#                 popup_86b5466439e57b6addeeb70534fbea6b.setContent(html_396236fb41b4673a4aed4cddaf7f68af);
#
#
#
#         circle_marker_896eda51b8f5a76640c7ef963dcb59eb.bindPopup(popup_86b5466439e57b6addeeb70534fbea6b)
#         ;
#
#
#
#
#             var circle_marker_a35a38baef0f5615ec6fda9d1c6d785e = L.circleMarker(
#                 [41.00095, -75.03],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bf6de959ce90e2ef6893212373d8f89c);
#
#
#         var popup_fb0761cca6cda196c028a97f201ba222 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecb57767a26cd59c567fd3484d85975c = $(`&lt;div id=&quot;html_ecb57767a26cd59c567fd3484d85975c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity (kWh): $2400000.0 | Power (kW): 400000.0&lt;/div&gt;`)[0];
#                 popup_fb0761cca6cda196c028a97f201ba222.setContent(html_ecb57767a26cd59c567fd3484d85975c);
#
#
#
#         circle_marker_a35a38baef0f5615ec6fda9d1c6d785e.bindPopup(popup_fb0761cca6cda196c028a97f201ba222)
#         ;
#
#
#
#
#             var circle_marker_c36a172440c56cec76bcae320bbe78d8 = L.circleMarker(
#                 [39.7060984, -105.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.296, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bf6de959ce90e2ef6893212373d8f89c);
#
#
#         var popup_4946295f05c64cc6613c75b26d306e2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_272e5c18fc8e2eda9af538104955e7e2 = $(`&lt;div id=&quot;html_272e5c18fc8e2eda9af538104955e7e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity (kWh): $1296000.0 | Power (kW): 324000.0&lt;/div&gt;`)[0];
#                 popup_4946295f05c64cc6613c75b26d306e2b.setContent(html_272e5c18fc8e2eda9af538104955e7e2);
#
#
#
#         circle_marker_c36a172440c56cec76bcae320bbe78d8.bindPopup(popup_4946295f05c64cc6613c75b26d306e2b)
#         ;
#
#
#
#
#             var circle_marker_730d662004f3d8c815e0511335bd2eaa = L.circleMarker(
#                 [37.069105, -121.08],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&q

# %%
# Import Data Set
import pandas as pd
energy = pd.read_csv('Global_Map_Full_Data_data.csv')

# Create folium map
import folium
map_energy = folium.Map(location=[36, -119], zoom_start=6) # coordinates focus near California

# Add markers for each project on the map
for _, row in energy.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Capacity (kWh): ${row['Rated Capacity (kWh)']} | Power (kW): {row['Rated Power (kW)']:.1f}"
    ).add_to(map_energy)

# Display the map
map_energy
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86369c1a3f61269f0aa5819911573abf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86369c1a3f61269f0aa5819911573abf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86369c1a3f61269f0aa5819911573abf = L.map(
#                 &quot;map_86369c1a3f61269f0aa5819911573abf&quot;,
#                 {
#                     center: [36.0, -119.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_690ae70eacd7676bbc46252ef70ae339 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_690ae70eacd7676bbc46252ef70ae339.addTo(map_86369c1a3f61269f0aa5819911573abf);
#
#
#             var marker_bcd0772d59fba4461819e626ce2836ec = L.marker(
#                 [37.4537502, -90.84],
#                 {}
#             ).addTo(map_86369c1a3f61269f0aa5819911573abf);
#
#
#         var popup_fcacafa0b4dbedcc005c5cfe1a7c3e60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cbd7496aab25066b9a3fe118066f8da = $(`&lt;div id=&quot;html_9cbd7496aab25066b9a3fe118066f8da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity (kWh): $3520000.0 | Power (kW): 440000.0&lt;/div&gt;`)[0];
#                 popup_fcacafa0b4dbedcc005c5cfe1a7c3e60.setContent(html_9cbd7496aab25066b9a3fe118066f8da);
#
#
#
#         marker_bcd0772d59fba4461819e626ce2836ec.bindPopup(popup_fcacafa0b4dbedcc005c5cfe1a7c3e60)
#         ;
#
#
#
#
#             var marker_89516ed2ff510cac6be0efab4e7fefa8 = L.marker(
#                 [41.00095, -75.03],
#                 {}
#             ).addTo(map_86369c1a3f61269f0aa5819911573abf);
#
#
#         var popup_b9d1987b6c454f47a52a10287e758cff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c9e937f22fc1e0001ccebae13610e73 = $(`&lt;div id=&quot;html_7c9e937f22fc1e0001ccebae13610e73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity (kWh): $2400000.0 | Power (kW): 400000.0&lt;/div&gt;`)[0];
#                 popup_b9d1987b6c454f47a52a10287e758cff.setContent(html_7c9e937f22fc1e0001ccebae13610e73);
#
#
#
#         marker_89516ed2ff510cac6be0efab4e7fefa8.bindPopup(popup_b9d1987b6c454f47a52a10287e758cff)
#         ;
#
#
#
#
#             var marker_c7e73ac5088775edc843b1ede82fcbca = L.marker(
#                 [39.7060984, -105.7],
#                 {}
#             ).addTo(map_86369c1a3f61269f0aa5819911573abf);
#
#
#         var popup_e659a4b7f7c87ba5905c19302f685e52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ccbafd2ef8a8ccf00ce3f4983dd3f7a = $(`&lt;div id=&quot;html_1ccbafd2ef8a8ccf00ce3f4983dd3f7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity (kWh): $1296000.0 | Power (kW): 324000.0&lt;/div&gt;`)[0];
#                 popup_e659a4b7f7c87ba5905c19302f685e52.setContent(html_1ccbafd2ef8a8ccf00ce3f4983dd3f7a);
#
#
#
#         marker_c7e73ac5088775edc843b1ede82fcbca.bindPopup(popup_e659a4b7f7c87ba5905c19302f685e52)
#         ;
#
#
#
#
#             var marker_d6f07007f45e4575488dfbda0dd117cb = L.marker(
#                 [37.069105, -121.08],
#                 {}
#             ).addTo(map_86369c1a3f61269f0aa5819911573abf);
#
#
#         var popup_1c63f2a305b0610e6548c23501d40685 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bcc031121f758dab6e423a16b3c4ad60 = $(`&lt;div id=&quot;html_bcc031121f758dab6e423a16b3c4ad60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity (kWh): $3392000.0 | Power (kW): 424000.0&lt;/div&gt;`)[0];
#                 popup_1c63f2a305b0610e6548c23501d40685.setContent(html_bcc031121f758dab6e423a16b3c4ad60);
#
#
#
#         marker_d6f07007f45e4575488dfbda0dd117cb.bindPopup(popup_1c63f2a305b0610e6548c23501d40685)
#         ;
#
#
#
#
#             var marker_5f22f6496c21c83d8dd00e604bfee009 = L.marker(
#                 [42.611429, -72.473883],
#                 {}
#             ).addTo(map_86369c1a3f61269f0aa5819911573abf);
#
#
#         var popup_c997a0aa9103d807716ddae0ab85b18a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c912048965c983b743e226c74790c8a = $(`&lt;div id=&quot;html_7c912048965c983b743e226c74790c8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity (kWh): $8482020.0 | Power (kW): 1119000.0&lt;/div&gt;`)[0];
#                 popup_c997a0aa9103d807716ddae0ab85b18a.setContent(html_7c912048965c983b743e226c74790c8a);
#
#
#
#         marker_5f22f6496c21c83d8dd00e604bfee009.bindPopup(popup_c997a0aa9103d807716ddae0ab85b18a)
#         ;
#
#
#
#
#             var marker
